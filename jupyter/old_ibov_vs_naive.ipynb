# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import pandas as pd 

from script.performance_tracker import PerformanceTracker

# %%
df = pd.read_excel("../data/base_dados2.xlsx", index_col="Date")

# %%
(1 + df.pct_change().dropna().mean(axis=1)).cumprod().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
col = "FRP0"

(1 + df[col].pct_change().dropna()).cumprod().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,100))
df.pct_change().dropna().mean().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
df.mean()[col]
# Out:
# 463.469987129987

# %%
df[""].pct_change()
# Out:
# Date
# 2018-04-29     9.333333
# 2018-05-06     8.666667
# 2018-05-13     6.266667
# 2018-05-20     3.366667
# 2018-05-27     1.733333
#                 ...
# 2023-03-12    20.833333
# 2023-03-19    13.366667
# 2023-03-26     5.800000
# 2023-04-02    22.266667
# 2023-04-09    17.000000
# Name: FRP0, Length: 259, dtype: float64
